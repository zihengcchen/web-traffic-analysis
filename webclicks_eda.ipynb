# %%
import pandas as pd
import os

# Define the folder containing the data files
data_folder = 'web-clicks-nov-2009'

# Initialize an empty list to hold the DataFrames
data_frames = []

# Initialize a list to hold the statistics for each day
click_stats = []

# Loop through the range of dates
for day in range(1, 23):
    # Construct the file name
    file_name = f'2009-11-{day:02d}.json'
    # Construct the full file path
    file_path = os.path.join(data_folder, file_name)
    # Read the JSON file into a DataFrame
    df = pd.read_json(file_path, lines=True)
    
    # Calculate max, min number of clicks, row count, and total clicks for the day
    max_clicks = df['count'].max()
    min_clicks = df['count'].min()
    row_count = len(df)
    total_clicks = df['count'].sum()
    
    click_stats.append({
        'date': file_name,
        'max_clicks': max_clicks,
        'min_clicks': min_clicks,
        'row_count': row_count,
        'total_clicks': total_clicks
    })
    
    # Append the DataFrame to the list
    data_frames.append(df)

# Concatenate all DataFrames into a single DataFrame
all_data = pd.concat(data_frames, ignore_index=True)

# Convert click_stats to a DataFrame for better display
click_stats_df = pd.DataFrame(click_stats)

# Display the statistics for each day
print(click_stats_df)
# Out:
#                date  max_clicks  min_clicks  row_count  total_clicks
# 0   2009-11-01.json      153477           1     806153      11591468
# 1   2009-11-02.json       87298           1    1135042      12324531
# 2   2009-11-03.json       72053           1    1137745      12372546
# 3   2009-11-04.json       66413           1    1141231      11367958
# 4   2009-11-05.json       57717           1    1136753      11409381
# 5   2009-11-06.json       55205           1    1038294      11058292
# 6   2009-11-07.json      309333           1     773577       8837583
# 7   2009-11-08.json       77416           1     866116      10040455
# 8   2009-11-09.json       70699           1    1172812      11754482
# 9   2009-11-10.json       76162           1    1137739      11364044
# 10  2009-11-11.json       64882           1    1184242      11847771
# 11  2009-11-12.json       54163           1    1155900      11421984
# 12  2009-11-13.json       49160           1    1025571      10813612
# 13  2009-11-14.json       44183           1     786678       8567745
# 14  2009-11-15.json       69411           1     878763      10090211
# 15  2009-11-16.json       66536           1    1197823      12100082
# 16  2009-11-17.json       64165           1    1181642      12009662
# 17  2009-11-18.json       70775           1    1203211      12169072
# 18  2009-11-19.json       66466           1    1145318      11561602
# 19  2009-11-20.json       51357           1    1063581      11178603
# 20  2009-11-21.json      172851           1     743189       8545400
# 21  2009-11-22.json       42203           1     222272       3076736

# %%
click_stats_df['row_count']
# Out:
# 0      806153
# 1     1135042
# 2     1137745
# 3     1141231
# 4     1136753
# 5     1038294
# 6      773577
# 7      866116
# 8     1172812
# 9     1137739
# 10    1184242
# 11    1155900
# 12    1025571
# 13     786678
# 14     878763
# 15    1197823
# 16    1181642
# 17    1203211
# 18    1145318
# 19    1063581
# 20     743189
# 21     222272
# Name: row_count, dtype: int64

# %%
import pandas as pd
import os

# Define the folder containing the data files
data_folder = 'web-clicks-nov-2009'

# Initialize an empty list to hold the DataFrames
data_frames = []

# Initialize a list to hold the statistics for each day
click_stats = []

# Loop through the range of dates
for day in range(1, 23):
    # Construct the file name
    file_name = f'2009-11-{day:02d}.json'
    # Construct the full file path
    file_path = os.path.join(data_folder, file_name)
    # Read the JSON file into a DataFrame
    df = pd.read_json(file_path, lines=True)
    
    # Calculate max, min number of clicks, row count, and total clicks for the day
    max_clicks = df['count'].max()
    min_clicks = df['count'].min()
    row_count = len(df)
    total_clicks = df['count'].sum()
    
    # Check for missing values
    missing_values = df.isnull().sum()
    missing_columns = missing_values[missing_values > 0].index.tolist()
    
    click_stats.append({
        'date': file_name,
        'max_clicks': max_clicks,
        'min_clicks': min_clicks,
        'row_count': row_count,
        'total_clicks': total_clicks,
        'missing_columns': missing_columns if missing_columns else None
    })
    
    # Append the DataFrame to the list
    data_frames.append(df)

# Concatenate all DataFrames into a single DataFrame
all_data = pd.concat(data_frames, ignore_index=True)

# Convert click_stats to a DataFrame for better display
click_stats_df = pd.DataFrame(click_stats)

# Display the statistics for each day
print(click_stats_df)
# Out:
#                date  max_clicks  min_clicks  row_count  total_clicks  \
# 0   2009-11-01.json      153477           1     806153      11591468
# 1   2009-11-02.json       87298           1    1135042      12324531
# 2   2009-11-03.json       72053           1    1137745      12372546
# 3   2009-11-04.json       66413           1    1141231      11367958
# 4   2009-11-05.json       57717           1    1136753      11409381
# 5   2009-11-06.json       55205           1    1038294      11058292
# 6   2009-11-07.json      309333           1     773577       8837583
# 7   2009-11-08.json       77416           1     866116      10040455
# 8   2009-11-09.json       70699           1    1172812      11754482
# 9   2009-11-10.json       76162           1    1137739      11364044
# 10  2009-11-11.json       64882           1    1184242      11847771
# 11  2009-11-12.json       54163           1    1155900      11421984
# 12  2009-11-13.json       49160           1    1025571      10813612
# 13  2009-11-14.json       44183           1     786678       8567745
# 14  2009-11-15.json       69411           1     878763      10090211
# 15  2009-11-16.json       66536           1    1197823      12100082
# 16  2009-11-17.json       64165           1    1181642      12009662
# 17  2009-11-18.json       70775           1    1203211      12169072
# 18  2009-11-19.json       66466           1    1145318      11561602
# 19  2009-11-20.json       51357           1    1063581      11178603
# 20  2009-11-21.json      172851           1     743189       8545400
# 21  2009-11-22.json       42203           1     222272       3076736
#
#    missing_columns
# 0             None
# 1             None
# 2             None
# 3             None
# 4             None
# 5             None
# 6             None
# 7             None
# 8             None
# 9             None
# 10            None
# 11            None
# 12            None
# 13            None
# 14            None
# 15            None
# 16            None
# 17            None
# 18            None
# 19            None
# 20            None
# 21            None
